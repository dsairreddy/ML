# %% [markdown]
# <a href="https://colab.research.google.com/github/dsairreddy/ML/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import random
x = []
y = []
[x.append(random.randint(5,25)) for _ in range(10)]
[y.append(random.randint(5,25)) for _ in range(10)]
print(x)
print(y)
plt.plot(x,y)
plt.scatter(x,y)
plt.bar(x,y)
# Out:
# [6, 20, 14, 25, 19, 7, 7, 21, 5, 20]
# [7, 8, 20, 25, 20, 18, 23, 12, 14, 22]
# <BarContainer object of 10 artists>
