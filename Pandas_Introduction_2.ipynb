# %% [markdown]
# <a href="https://colab.research.google.com/github/dsairreddy/ML/blob/main/Pandas_Introduction_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: /content/drive/MyDrive/Credit_Card_Applications.csv import pasndas as pd into ds

import pandas as pd


ds = pd.read_csv('/content/drive/MyDrive/Credit_Card_Applications.csv')

# %%
#info()- for information
#.shape- total no of methods
# load column pd.set_option(' display .max_column',15)
ds.shape
ds.info()
#.            pd.set_option('display.max_rows',50) these two are for only Jupiter Notebook
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  690 non-null    int64
#  1   A1          690 non-null    int64
#  2   A2          690 non-null    float64
#  3   A3          690 non-null    float64
#  4   A4          690 non-null    int64
#  5   A5          690 non-null    int64
#  6   A6          690 non-null    int64
#  7   A7          690 non-null    float64
#  8   A8          690 non-null    int64
#  9   A9          690 non-null    int64
#  10  A10         690 non-null    int64
#  11  A11         690 non-null    int64
#  12  A12         690 non-null    int64
#  13  A13         690 non-null    int64
#  14  A14         690 non-null    int64
#  15  Class       690 non-null    int64
# dtypes: float64(3), int64(13)
# memory usage: 86.4 KB

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
ds.head(4)
# Out:
#    CustomerID  A1     A2     A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0    15776156   1  22.08  11.46   2   4   4  1.585   0   0    0    1    2
# 1    15739548   0  22.67   7.00   2   8   4  0.165   0   0    0    0    2
# 2    15662854   0  29.58   1.75   1   4   4  1.250   0   0    0    1    2
# 3    15687688   0  21.67  11.50   1   5   3  0.000   1   1   11    1    2
#
#    A13   A14  Class
# 0  100  1213      0
# 1  160     1      0
# 2  280     1      0
# 3    0     1      1

# %%
ds.tail(4)
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13  A14  Class
# 686    0   45      0
# 687  100    1      1
# 688  120   12      1
# 689  560    1      1

# %%
#head() to see the top valus
#tail() to see bottom values

# %%
import random
age=[]
height=[]
weight=[]
speed=[]
for _ in range (100):
   age.append(random.randint(0,100))
   height.append(random.randint(0,100))
   weight.append(random.randint(0,100))
   speed.append(random.randint(0,100))

idata={'Age':age,'height': height,'weight': weight,'speed':speed}

# %%
idata
# Out:
# {'Age': [91,
#   70,
#   35,
#   48,
#   2,
#   59,
#   24,
#   98,
#   43,
#   5,
#   24,
#   36,
#   19,
#   48,
#   32,
#   96,
#   97,
#   13,
#   27,
#   16,
#   27,
#   43,
#   6,
#   100,
#   16,
#   91,
#   91,
#   4,
#   78,
#   86,
#   49,
#   35,
#   54,
#   32,
#   71,
#   20,
#   54,
#   41,
#   75,
#   50,
#   46,
#   2,
#   91,
#   40,
#   93,
#   12,
#   90,
#   84,
#   46,
#   10,
#   90,
#   86,
#   75,
#   78,
#   84,
#   62,
#   10,
#   4,
#   74,
#   11,
#   5,
#   19,
#   98,
#   96,
#   71,
#   32,
#   19,
#   11,
#   58,
#   56,
#   58,
#   22,
#   75,
#   1,
#   83,
#   93,
#   16,
#   56,
#   82,
#   85,
#   54,
#   74,
#   34,
#   90,
#   15,
#   7,
#   47,
#   23,
#   96,
#   99,
#   48,
#   37,
#   23,
#   39,
#   76,
#   83,
#   59,
#   7,
#   45,
#   64],
#  'height': [76,
#   89,
#   4,
#   59,
#   58,
#   55,
#   32,
#   68,
#   81,
#   46,
#   18,
#   51,
#   17,
#   32,
#   47,
#   76,
#   87,
#   45,
#   73,
#   19,
#   87,
#   81,
#   55,
#   40,
#   7,
#   85,
#   92,
#   99,
#   48,
#   49,
#   83,
#   28,
#   33,
#   29,
#   31,
#   25,
#   76,
#   3,
#   68,
#   67,
#   32,
#   83,
#   34,
#   56,
#   35,
#   47,
#   26,
#   60,
#   20,
#   0,
#   17,
#   9,
#   75,
#   49,
#   6,
#   94,
#   26,
#   82,
#   61,
#   81,
#   63,
#   12,
#   15,
#   91,
#   13,
#   97,
#   44,
#   10,
#   42,
#   30,
#   77,
#   21,
#   20,
#   64,
#   9,
#   39,
#   57,
#   21,
#   1,
#   88,
#   56,
#   31,
#   53,
#   28,
#   60,
#   75,
#   40,
#   92,
#   77,
#   67,
#   57,
#   98,
#   57,
#   43,
#   50,
#   2,
#   21,
#   33,
#   76,
#   51],
#  'weight': [81,
#   74,
#   46,
#   67,
#   10,
#   41,
#   57,
#   29,
#   9,
#   43,
#   0,
#   68,
#   9,
#   23,
#   49,
#   71,
#   37,
#   58,
#   13,
#   96,
#   27,
#   73,
#   18,
#   89,
#   96,
#   76,
#   6,
#   30,
#   68,
#   13,
#   80,
#   96,
#   99,
#   8,
#   91,
#   48,
#   78,
#   24,
#   59,
#   76,
#   87,
#   9,
#   60,
#   35,
#   18,
#   100,
#   90,
#   9,
#   30,
#   83,
#   77,
#   12,
#   92,
#   94,
#   21,
#   43,
#   93,
#   58,
#   74,
#   72,
#   26,
#   63,
#   58,
#   64,
#   79,
#   60,
#   57,
#   76,
#   68,
#   78,
#   15,
#   23,
#   88,
#   2,
#   22,
#   4,
#   91,
#   72,
#   66,
#   29,
#   65,
#   41,
#   96,
#   6,
#   52,
#   55,
#   81,
#   11,
#   96,
#   20,
#   79,
#   45,
#   100,
#   85,
#   90,
#   20,
#   56,
#   13,
#   61,
#   72],
#  'speed': [2,
#   91,
#   100,
#   35,
#   67,
#   72,
#   75,
#   95,
#   14,
#   29,
#   41,
#   88,
#   63,
#   46,
#   43,
#   58,
#   28,
#   78,
#   69,
#   64,
#   100,
#   55,
#   40,
#   32,
#   58,
#   14,
#   78,
#   89,
#   54,
#   48,
#   51,
#   61,
#   98,
#   16,
#   11,
#   19,
#   99,
#   74,
#   14,
#   90,
#   12,
#   79,
#   100,
#   20,
#   22,
#   38,
#   41,
#   62,
#   89,
#   19,
#   13,
#   91,
#   33,
#   76,
#   91,
#   59,
#   87,
#   87,
#   65,
#   36,
#   4,
#   36,
#   49,
#   47,
#   4,
#   74,
#   20,
#   18,
#   80,
#   62,
#   31,
#   96,
#   8,
#   66,
#   0,
#   17,
#   41,
#   27,
#   15,
#   12,
#   45,
#   47,
#   26,
#   13,
#   76,
#   65,
#   54,
#   27,
#   34,
#   34,
#   85,
#   93,
#   84,
#   80,
#   19,
#   91,
#   47,
#   49,
#   27,
#   34]}

# %%
df1=pd.DataFrame(idata)
df1
# Out:
#     Age  height  weight  speed
# 0    91      76      81      2
# 1    70      89      74     91
# 2    35       4      46    100
# 3    48      59      67     35
# 4     2      58      10     67
# ..  ...     ...     ...    ...
# 95   83       2      20     91
# 96   59      21      56     47
# 97    7      33      13     49
# 98   45      76      61     27
# 99   64      51      72     34
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  height  weight  speed
# 0   91      76      81      2
# 1   70      89      74     91
# 2   35       4      46    100
# 3   48      59      67     35
# 4    2      58      10     67
# 5   59      55      41     72
# 6   24      32      57     75
# 7   98      68      29     95
# 8   43      81       9     14
# 9    5      46      43     29

# %%
df1.tail(10)
# Out:
#     Age  height  weight  speed
# 90   48      57      79     85
# 91   37      98      45     93
# 92   23      57     100     84
# 93   39      43      85     80
# 94   76      50      90     19
# 95   83       2      20     91
# 96   59      21      56     47
# 97    7      33      13     49
# 98   45      76      61     27
# 99   64      51      72     34

# %%
df1.describe()
# Out:
#               Age      height     weight       speed
# count  100.000000  100.000000  100.00000  100.000000
# mean    50.500000   48.930000   53.78000   51.160000
# std     31.063148   27.507668   30.29304   29.139414
# min      1.000000    0.000000    0.00000    0.000000
# 25%     22.750000   27.500000   23.75000   27.000000
# 50%     48.000000   49.000000   58.50000   48.500000
# 75%     79.000000   75.000000   78.25000   76.500000
# max    100.000000   99.000000  100.00000  100.000000

# %%
df1['Age']
# Out:
# 0     91
# 1     70
# 2     35
# 3     48
# 4      2
#       ..
# 95    83
# 96    59
# 97     7
# 98    45
# 99    64
# Name: Age, Length: 100, dtype: int64

# %%
df2=df1[['Age','speed']]
df2
# Out:
#     Age  speed
# 0    91      2
# 1    70     91
# 2    35    100
# 3    48     35
# 4     2     67
# ..  ...    ...
# 95   83     91
# 96   59     47
# 97    7     49
# 98   45     27
# 99   64     34
#
# [100 rows x 2 columns]

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  height  weight  speed
# 99   64      51      72     34
# 98   45      76      61     27
# 97    7      33      13     49
# 96   59      21      56     47
# 95   83       2      20     91
# ..  ...     ...     ...    ...
# 4     2      58      10     67
# 3    48      59      67     35
# 2    35       4      46    100
# 1    70      89      74     91
# 0    91      76      81      2
#
# [100 rows x 4 columns]

# %%
df2[0::2].describe()
# Out:
#              Age       speed
# count  50.000000   50.000000
# mean   53.520000   48.140000
# std    29.210174   31.176921
# min     2.000000    0.000000
# 25%    27.000000   20.500000
# 50%    54.000000   44.000000
# 75%    77.500000   75.750000
# max    98.000000  100.000000

# %%
#Filter
filter1=df1['weight']>50

# %%
df1.loc[filter1]
# Out:
#     Age  height  weight  speed
# 0    91      76      81      2
# 1    70      89      74     91
# 3    48      59      67     35
# 6    24      32      57     75
# 11   36      51      68     88
# 15   96      76      71     58
# 17   13      45      58     78
# 19   16      19      96     64
# 21   43      81      73     55
# 23  100      40      89     32
# 24   16       7      96     58
# 25   91      85      76     14
# 28   78      48      68     54
# 30   49      83      80     51
# 31   35      28      96     61
# 32   54      33      99     98
# 34   71      31      91     11
# 36   54      76      78     99
# 38   75      68      59     14
# 39   50      67      76     90
# 40   46      32      87     12
# 42   91      34      60    100
# 45   12      47     100     38
# 46   90      26      90     41
# 49   10       0      83     19
# 50   90      17      77     13
# 52   75      75      92     33
# 53   78      49      94     76
# 56   10      26      93     87
# 57    4      82      58     87
# 58   74      61      74     65
# 59   11      81      72     36
# 61   19      12      63     36
# 62   98      15      58     49
# 63   96      91      64     47
# 64   71      13      79      4
# 65   32      97      60     74
# 66   19      44      57     20
# 67   11      10      76     18
# 68   58      42      68     80
# 69   56      30      78     62
# 72   75      20      88      8
# 76   16      57      91     41
# 77   56      21      72     27
# 78   82       1      66     15
# 80   54      56      65     45
# 82   34      53      96     26
# 84   15      60      52     76
# 85    7      75      55     65
# 86   47      40      81     54
# 88   96      77      96     34
# 90   48      57      79     85
# 92   23      57     100     84
# 93   39      43      85     80
# 94   76      50      90     19
# 96   59      21      56     47
# 98   45      76      61     27
# 99   64      51      72     34

# %%
filter2=df1['Age']>50

# %%
df1.loc[filter1|filter2]
# Out:
#     Age  height  weight  speed
# 0    91      76      81      2
# 1    70      89      74     91
# 3    48      59      67     35
# 5    59      55      41     72
# 6    24      32      57     75
# ..  ...     ...     ...    ...
# 94   76      50      90     19
# 95   83       2      20     91
# 96   59      21      56     47
# 98   45      76      61     27
# 99   64      51      72     34
#
# [76 rows x 4 columns]
